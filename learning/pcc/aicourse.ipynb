# %%
Participants = ['John', 'Seraphina', 'Blyke', 'Arlo', 'Rei', 'Isen', 'Kuyo']
# Out:
# ['Seraphina', 'Blyke']

# %%
Participants
# Out:
# ['John', 'Seraphina', 'Blyke', 'Arlo', 'Rei', 'Isen', 'Kuyo']

# %%
print(Participants[1:3])
# Out:
# ['Seraphina', 'Blyke']

# %%
Participants[-1:
    ]
# Out:
# ['John', 'Seraphina', 'Blyke', 'Arlo', 'Rei', 'Isen']

# %%
Participants[2:]
# Out:
# ['Blyke', 'Arlo', 'Rei', 'Isen', 'Kuyo']

# %%
Participants.index("Blyke")
# Out:
# 2

# %%
Newcomers = ['Val', 'Doc']

# %%
Newcomers
# Out:
# ['Val', 'Doc']

# %%
Main_list = [Participants, Newcomers]
Main_list
# Out:
# [['John', 'Seraphina', 'Blyke', 'Arlo', 'Rei', 'Isen', 'Kuyo'], ['Val', 'Doc']]

# %%
Participants.sort()
Participants
# Out:
# ['Arlo', 'Blyke', 'Isen', 'John', 'Kuyo', 'Rei', 'Seraphina']

# %%
Participants.sort(reverse=True)

# %%
Participants
# Out:
# ['Seraphina', 'Rei', 'Kuyo', 'John', 'Isen', 'Blyke', 'Arlo']

# %%
Numbers = [124,34,7,5,3,9,30,43,40,0]
Numbers.sort()
Numbers
# Out:
# [0, 3, 5, 7, 9, 30, 34, 40, 43, 124]

# %%
Numbers.sort(reverse=True)
Numbers
# Out:
# [124, 43, 40, 34, 30, 9, 7, 5, 3, 0]

# %%
Number = [15, 40, 50, 100, 115, 140]
print(Number[3:5])
# Out:
# [100, 115]

# %%
Number[:4]
# Out:
# [15, 40, 50, 100]

# %%
Number[4:]
# Out:
# [115, 140]

# %%
Number[-4:]
# Out:
# [50, 100, 115, 140]

# %%
Number.index(15)
# Out:
# 0

# %%
Two_Numbers = [1,2]

# %%
ALL_Numbers = [Two_Numbers, Number]
ALL_Numbers
# Out:
# [[1, 2], [15, 40, 50, 100, 115, 140]]

# %%
Number.sort(reverse=True)
Number
# Out:
# [140, 115, 100, 50, 40, 15]

# %%
x = (45,67,34)
x
# Out:
# (45, 67, 34)

# %%
y = 34,803,920

# %%
y
# Out:
# (34, 803, 920)

# %%
a, b,c = [23,45,67], [32,67,23], [32,3,432,45,44]
a
# Out:
# [23, 45, 67]

# %%
a[2]
# Out:
# 67

# %%
List_1 = [x,y]
List_1
# Out:
# [(45, 67, 34), (34, 803, 920)]

# %%
(age, years_of_school) = "30,17".split(',')
print(age)
print(years_of_school)
# Out:
# 30
# 17

# %%
def circle_info(x):
    pi = 3.144
    A = pi*(x**2)
    C = 2*pi*x
    print("Area and Circumference:")
    return A, C

# %%
circle_info(9)
# Out:
# Area and Circumference:
# (254.66400000000002, 56.592)

# %%
dict = {'k1': "cat", 'k2': "dog", 'k3': "mouse", 'k4': "fish"}

# %%
dict
# Out:
# {'k1': 'cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish'}

# %%
dict['k3']
# Out:
# 'mouse'

# %%
dict['k5']= 'parrot'
dict
# Out:
# {'k1': 'cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish', 'k5': 'parrot'}

# %%
cars = {'c1': "mercedes", 'c2':"lamborgini"}
cars
# Out:
# {'c1': 'mercedes', 'c2': 'lamborgini'}

# %%
cars['c2'] = 'benz'
cars
# Out:
# {'c1': 'mercedes', 'c2': 'benz', 'k2': 'benz'}

# %%
dep_workers = {'dep_1': 'Peter', 'dep_2': ['Jenifer', 'Michael', 'Tommy']}
dep_workers
# Out:
# {'dep_1': 'Peter', 'dep_2': ['Jenifer', 'Michael', 'Tommy']}

# %%
dep_workers['dep_2']
# Out:
# ['Jenifer', 'Michael', 'Tommy']

# %%
Team = {}
Team['Defenders'] = ['Rudiger', 'Yoro', 'Maguire', 'Araujo']
Team['Goal Keepers'] = ['Courtois', 'Lemmens', 'Donnaruma']
Team['Midfielders'] = ['Bruno Fernandes', 'Mainoo', 'Bellingham', 'Pedri']
Team['Attackers'] = ['Mbappe', 'Haaland', 'Mbeumo', 'Sesko']
Team
# Out:
# {'Defenders': ['Rudiger', 'Yoro', 'Maguire', 'Araujo'],
#  'Goal Keepers': ['Courtois', 'Lemmens', 'Donnaruma'],
#  'Midfielders': ['Bruno Fernandes', 'Mainoo', 'Bellingham', 'Pedri'],
#  'Attackers': ['Mbappe', 'Haaland', 'Mbeumo', 'Sesko']}

# %%
Team['Attackers']
# Out:
# ['Mbappe', 'Haaland', 'Mbeumo', 'Sesko']

# %%
print (Team)
# Out:
# {'Defenders': ['Rudiger', 'Yoro', 'Maguire', 'Araujo'], 'Goal Keepers': ['Courtois', 'Lemmens', 'Donnaruma'], 'Midfielders': ['Bruno Fernandes', 'Mainoo', 'Bellingham', 'Pedri'], 'Attackers': ['Mbappe', 'Haaland', 'Mbeumo', 'Sesko']}

# %%
print (Team['Midfielders'])
# Out:
# ['Bruno Fernandes', 'Mainoo', 'Bellingham', 'Pedri']

# %%
print (Team.get('Defenders'))
# Out:
# ['Rudiger', 'Yoro', 'Maguire', 'Araujo']

# %%
print (Team.get('Attackers'))
# Out:
# ['Mbappe', 'Haaland', 'Mbeumo', 'Sesko']
